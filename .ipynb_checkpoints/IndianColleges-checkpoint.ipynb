# %%
import requests
from bs4 import BeautifulSoup
#http://www.studyguideindia.com/Colleges/Arts-Science/

# %%
url = ['http://www.studyguideindia.com/Colleges/Arts-Science/r-g-shah-science-college.html','http://www.studyguideindia.com/Colleges/Polytechnic/udaya-polytechnic-college-kaniyakumari.html']

# %%
count = 0
for li in url:
    x = requests.get(url)
    html_doc = x.text
    soup = BeautifulSoup(html_doc)
    get = soup.find_all('table', {'class' : 'altcolor1'})
    st_get = BeautifulSoup(str(get[0]))
    gg = st_get.find_all('td')
    count += 1

# %%
#print(soup.prettify())

# %%
#print(get[0])

# %%
count = -1
    data = []
    for i in gg:
        count += 1
        if count <= len(gg)-1:
            data.append(gg[count].get_text().strip())
            
    t = []
    for s in data:
        s.strip() 
        t.append(s)
        
    lis_key = []
    lis_value = []
    #dict['key3'] = 'Geeks'
    i=-2
    for p in t:
        i += 2
        if i < len(t):
            print(t[i])
            lis_key.append(t[i])

    i=-1
    for p in t:
        i += 2
        if i < len(t):
            print(t[i])
            lis_value.append(t[i])
            
            
    dic = {}

    p = 0
    for i in lis_key:
        dic [i] = lis_value[p]
        p += 1
        
    

    data_list.append(dic)

# %%
gg = st_get.find_all('td')

# %%
#print(t)

# %%
print(dic)
# Out:
# {'College Name': 'R G Shah Science College', 'Type of Institution': 'Arts & Science', 'Address': 'Gheekanta Road Verna\n\r\n                    Ahmedabad (Dist)\r\n                    \r\n                    \r\n                    Gujarat', 'Approved By': 'AICTE'}

# %%
data_list
# Out:
# [{'College Name': 'R G Shah Science College',
#   'Type of Institution': 'Arts & Science',
#   'Address': 'Gheekanta Road Verna\n\r\n                    Ahmedabad (Dist)\r\n                    \r\n                    \r\n                    Gujarat',
#   'Approved By': 'AICTE'}]

# %%
li = ['A','B','C','D','E']
for i in li:
    ul = []
    for j in range(5):
        ul.append(j)
        print(i,j)
        
        for k in ul:
            kl = []
            print(i,k,j)
            for l in range(6,11):
                kl.append(l)
                print(i,j,k,l)
# Out:
# A 0
# A 0 0
# A 0 0 6
# A 0 0 7
# A 0 0 8
# A 0 0 9
# A 0 0 10
# A 1
# A 0 1
# A 1 0 6
# A 1 0 7
# A 1 0 8
# A 1 0 9
# A 1 0 10
# A 1 1
# A 1 1 6
# A 1 1 7
# A 1 1 8
# A 1 1 9
# A 1 1 10
# A 2
# A 0 2
# A 2 0 6
# A 2 0 7
# A 2 0 8
# A 2 0 9
# A 2 0 10
# A 1 2
# A 2 1 6
# A 2 1 7
# A 2 1 8
# A 2 1 9
# A 2 1 10
# A 2 2
# A 2 2 6
# A 2 2 7
# A 2 2 8
# A 2 2 9
# A 2 2 10
# A 3
# A 0 3
# A 3 0 6
# A 3 0 7
# A 3 0 8
# A 3 0 9
# A 3 0 10
# A 1 3
# A 3 1 6
# A 3 1 7
# A 3 1 8
# A 3 1 9
# A 3 1 10
# A 2 3
# A 3 2 6
# A 3 2 7
# A 3 2 8
# A 3 2 9
# A 3 2 10
# A 3 3
# A 3 3 6
# A 3 3 7
# A 3 3 8
# A 3 3 9
# A 3 3 10
# A 4
# A 0 4
# A 4 0 6
# A 4 0 7
# A 4 0 8
# A 4 0 9
# A 4 0 10
# A 1 4
# A 4 1 6
# A 4 1 7
# A 4 1 8
# A 4 1 9
# A 4 1 10
# A 2 4
# A 4 2 6
# A 4 2 7
# A 4 2 8
# A 4 2 9
# A 4 2 10
# A 3 4
# A 4 3 6
# A 4 3 7
# A 4 3 8
# A 4 3 9
# A 4 3 10
# A 4 4
# A 4 4 6
# A 4 4 7
# A 4 4 8
# A 4 4 9
# A 4 4 10
# B 0
# B 0 0
# B 0 0 6
# B 0 0 7
# B 0 0 8
# B 0 0 9
# B 0 0 10
# B 1
# B 0 1
# ...

# %%
for i,j in
